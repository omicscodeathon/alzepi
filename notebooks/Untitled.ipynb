# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /home/KWTRP/kkimani/miniconda3/envs/alzepi/lib/python3.12/site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/KWTRP/kkimani/miniconda3/envs/alzepi/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/KWTRP/kkimani/miniconda3/envs/alzepi/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/KWTRP/kkimani/miniconda3/envs/alzepi/lib/python3.12/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /home/KWTRP/kkimani/miniconda3/envs/alzepi/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 17.1 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 14.0 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 4.8 MB/s eta 0:00:00eta 0:00:01
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 pyparsing-3.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from io import StringIO

# %%
import re

# %%
###this an example to reference from
'''
import pandas as pd

# Path to the uploaded .txt file
file_path = '/mnt/data/genomic_data.txt'

# Read the file and extract headers and data
with open(file_path, 'r') as file:
    lines = file.readlines()

# Extract headers
headers = lines[0].strip().split(',')

# Extract data rows
data = [line.strip().split(',') for line in lines[1:]]

# Create DataFrame
df = pd.DataFrame(data, columns=headers)

# Display the DataFrame
df.head()'''
# Out:
# "\nimport pandas as pd\n\n# Path to the uploaded .txt file\nfile_path = '/mnt/data/genomic_data.txt'\n\n# Read the file and extract headers and data\nwith open(file_path, 'r') as file:\n    lines = file.readlines()\n\n# Extract headers\nheaders = lines[0].strip().split(',')\n\n# Extract data rows\ndata = [line.strip().split(',') for line in lines[1:]]\n\n# Create DataFrame\ndf = pd.DataFrame(data, columns=headers)\n\n# Display the DataFrame\ndf.head()"

# %%
#read the .txt file
file_path = '../SraRunTable.txt'

# A funtion that only separate field with commas outiside quatation marks
def parse_line(line):
    # Regular expression to match quoted fields and commas
    pattern = re.compile(r'(?:,|\n|\r)(?=(?:[^"]*"[^"]*")*[^"]*$)')
    # Split on commas that are not inside quotes
    return pattern.split(line.strip())

# Read the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Extract headers (first line) and process it
headers = parse_line(lines[0])

# Extract and process data rows
data = [parse_line(line) for line in lines[1:]]

# Create DataFrame
df = pd.DataFrame(data, columns=headers)

# Display the DataFrame
print(df)
# Out:
#              Run AGE Assay Type AvgSpotLen        Bases    BioProject  \
# 0    SRR29492859  72   ATAC-seq        302  12024364050  PRJNA1126662
# 1    SRR29492860  74   ATAC-seq        302  28509790560  PRJNA1126662
# 2    SRR29492861  68   ATAC-seq        302  19779971086  PRJNA1126662
# 3    SRR29492862  68   ATAC-seq        302  21656236082  PRJNA1126662
# 4    SRR29492863  70   ATAC-seq        302  21103510850  PRJNA1126662
# ..           ...  ..        ...        ...          ...           ...
# 130  SRR29492989  66    RNA-Seq        302  11943702568  PRJNA1126662
# 131  SRR29492990  53    RNA-Seq        302  13683245218  PRJNA1126662
# 132  SRR29492991  68    RNA-Seq        302  14274701044  PRJNA1126662
# 133  SRR29492992  56    RNA-Seq        302  11411644102  PRJNA1126662
# 134  SRR29492993  57    RNA-Seq        302  11205041976  PRJNA1126662
#
#         BioSample        Bytes  \
# 0    SAMN41984448   4345973968
# 1    SAMN41984449  10020716894
# 2    SAMN41984450   7355247238
# 3    SAMN41984451   7449894545
# 4    SAMN41984452   7279888224
# ..            ...          ...
# 130  SAMN41984573   4360650540
# 131  SAMN41984574   5012978742
# 132  SAMN41984575   5211810828
# 133  SAMN41984576   4161919563
# 134  SAMN41984577   4120518963
#
#                                            Center Name Collection_Date  ...  \
# 0    "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 1    "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 2    "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 3    "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 4    "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# ..                                                 ...             ...  ...
# 130  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 131  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 132  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 133  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 134  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
#
#          Organism  Platform           ReleaseDate           create_date  \
# 0    Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:18:00Z
# 1    Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:48:00Z
# 2    Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:40:00Z
# 3    Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:37:00Z
# 4    Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:25:00Z
# ..            ...       ...                   ...                   ...
# 130  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:20:00Z
# 131  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:26:00Z
# 132  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:16:00Z
# 133  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:13:00Z
# 134  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:17:00Z
#
#     version Sample Name     sex   source_name  SRA Study        tissue
# 0         1  GSM8343350    male  Isolated WBC  SRP515320  Isolated WBC
# 1         1  GSM8343349    male  Isolated WBC  SRP515320  Isolated WBC
# 2         1  GSM8343348  female  Isolated WBC  SRP515320  Isolated WBC
# 3         1  GSM8343347  female  Isolated WBC  SRP515320  Isolated WBC
# 4         1  GSM8343346    male  Isolated WBC  SRP515320  Isolated WBC
# ..      ...         ...     ...           ...        ...           ...
# 130       1  GSM8343225    male   Whole blood  SRP515320   Whole blood
# 131       1  GSM8343224  female   Whole blood  SRP515320   Whole blood
# 132       1  GSM8343223  female   Whole blood  SRP515320   Whole blood
# 133       1  GSM8343222  female   Whole blood  SRP515320   Whole blood
# 134       1  GSM8343221  female   Whole blood  SRP515320   Whole blood
#
# [135 rows x 33 columns]

# %%
df.head()
# Out:
#            Run AGE Assay Type AvgSpotLen        Bases    BioProject  \
# 0  SRR29492859  72   ATAC-seq        302  12024364050  PRJNA1126662
# 1  SRR29492860  74   ATAC-seq        302  28509790560  PRJNA1126662
# 2  SRR29492861  68   ATAC-seq        302  19779971086  PRJNA1126662
# 3  SRR29492862  68   ATAC-seq        302  21656236082  PRJNA1126662
# 4  SRR29492863  70   ATAC-seq        302  21103510850  PRJNA1126662
#
#       BioSample        Bytes  \
# 0  SAMN41984448   4345973968
# 1  SAMN41984449  10020716894
# 2  SAMN41984450   7355247238
# 3  SAMN41984451   7449894545
# 4  SAMN41984452   7279888224
#
#                                          Center Name Collection_Date  ...  \
# 0  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 1  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 2  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 3  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
# 4  "HEALTHSPAN BIOLOGY, HEALTH AND EXERCISE SCIEN...         missing  ...
#
#        Organism  Platform           ReleaseDate           create_date version  \
# 0  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:18:00Z       1
# 1  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:48:00Z       1
# 2  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:40:00Z       1
# 3  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:37:00Z       1
# 4  Homo sapiens  ILLUMINA  2024-08-01T00:00:00Z  2024-06-21T17:25:00Z       1
#
#   Sample Name     sex   source_name  SRA Study        tissue
# 0  GSM8343350    male  Isolated WBC  SRP515320  Isolated WBC
# 1  GSM8343349    male  Isolated WBC  SRP515320  Isolated WBC
# 2  GSM8343348  female  Isolated WBC  SRP515320  Isolated WBC
# 3  GSM8343347  female  Isolated WBC  SRP515320  Isolated WBC
# 4  GSM8343346    male  Isolated WBC  SRP515320  Isolated WBC
#
# [5 rows x 33 columns]

# %%
df.to_csv('../data/human_alzheimer.csv')
